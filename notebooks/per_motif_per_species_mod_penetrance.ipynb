# %%
import os, sys, pysam, matplotlib.pyplot as plt, numpy as np, pandas as pd, seaborn as sns
from glob import glob
from Bio import SeqIO

# %%
def get_motifs(ref, seq, motif2pos):
    """Return position of motifs in sequence"""
    motifs = {m: set() for m in motif2pos}
    motifs_lens = set(len(m) for m in motifs)#; print(motifs_lens)
    # only count + strand
    strand = "+"
    for s in range(len(seq)-min(motifs_lens)):
        for l in motifs_lens:
            m = seq[s:s+l]
            if m in motifs:
                pos = "%s:%s%s"%(ref, s+motif2pos[m], strand)
                motifs[m].add(pos)
    return motifs

def fasta2data(fasta, motif2pos):
    """Return """
    s2d, s2c = {}, {}
    for r in SeqIO.parse(fasta, "fasta"):
        ref = r.name
        seq = str(r.seq)
        family, species = r.description.split()[1:3]
        spname = "%s%s"%(family.lower()[0], species)
        sys.stderr.write(" %s %s     \r"%(spname, ref))
        # get motifs
        motifs = get_motifs(ref, seq, motif2pos)
        # update species motifs
        if spname in s2d: 
            for m in motif2pos: 
                s2d[spname][m] = s2d[spname][m].union(motifs[m])
        # all motifs are fresh here
        else: 
            s2d[spname] = motifs #{m: set() for m in motif2pos}
            s2c[spname] = []
        s2c[spname].append(ref)
    return s2d, s2c

fasta = "/home/lpryszcz/cluster/dna_mods/ref/mock_community.fa"

mod2mers = {"6mA": ((2, "GATC"), ), "5mC": ((2, "CCAGG"), (2, "CCTGG"), (1, "CG"))}; mod2mers
motif2pos = {m: p for mod in mod2mers for p, m in mod2mers[mod]}; motif2pos

species2motifs, species2refs = fasta2data(fasta, motif2pos)
# Out:
#  lfermentum NZ_BJLV01000146.1

# %%
# #/home/lpryszcz/cluster/dna_mods/ecoli/modPhred.2020/PRJNA477598/
fn = "/home/lpryszcz/cluster/dna_mods/ecoli/modPhred.2020/PRJEB22772/mod.gz" # PRJNA477598 PRJEB22772
df = pd.read_csv(fn, sep="\t", skiprows=16)#; df.head() 
# get ref as chr:pos + strand
df["ref"] = df['chr'].astype(str) + ":" + df['pos'].astype(str) + df['strand']; df.head()
# Out:
#            chr  pos ref_base strand  mod  \
# 0  NC_000913.3  244        C      -  5mC
# 1  NC_000913.3  420        C      +  5mC
# 2  NC_000913.3  422        C      -  5mC
# 3  NC_000913.3  423        C      -  5mC
# 4  NC_000913.3  475        C      +  5mC
#
#    modPhred/PRJEB22772/minimap2/MARC_ZFscreens_R9.4_1D-Ecoli-run_FAF05145.bam depth  \
# 0                                                444
# 1                                                464
# 2                                                351
# 3                                                455
# 4                                                432
#
#    modPhred/PRJEB22772/minimap2/MARC_ZFscreens_R9.4_1D-Ecoli-run_FAF05145.bam basecall_accuracy  \
# 0                                              0.910
# 1                                              0.978
# 2                                              0.604
# 3                                              0.993
# 4                                              0.942
#
#    modPhred/PRJEB22772/minimap2/MARC_ZFscreens_R9.4_1D-Ecoli-run_FAF05145.bam mod_frequency  \
# 0                                              0.014
# 1                                              0.713
# 2                                              0.328
# 3                                              0.022
# 4                                              0.664
#
#    modPhred/PRJEB22772/minimap2/MARC_ZFscreens_R9.4_1D-Ecoli-run_FAF05145.bam median_mod_prob  \
# 0                                              0.833
# 1                                              0.967
# 2                                              0.833
# 3                                              0.683
# 4                                              0.933
#
#    modPhred/PRJEB22772/minimap2/MARC_ZFscreens_R9.4_2D-Ecoli-run_FAF05711.bam depth  \
# 0                                                120
# 1                                                132
# 2                                                103
# 3                                                123
# 4                                                126
#
#    modPhred/PRJEB22772/minimap2/MARC_ZFscreens_R9.4_2D-Ecoli-run_FAF05711.bam basecall_accuracy  \
# 0                                              0.958
# 1                                              0.962
# 2                                              0.621
# 3                                              0.984
# 4                                              0.937
#
#    modPhred/PRJEB22772/minimap2/MARC_ZFscreens_R9.4_2D-Ecoli-run_FAF05711.bam mod_frequency  \
# 0                                              0.050
# 1                                              0.644
# 2                                              0.369
# 3                                              0.057
# 4                                              0.635
#
#    modPhred/PRJEB22772/minimap2/MARC_ZFscreens_R9.4_2D-Ecoli-run_FAF05711.bam median_mod_prob  \
# 0                                              0.600
# 1                                              0.967
# 2                                              0.867
# 3                                              0.767
# 4                                              0.967
#
#                 ref
# 0  NC_000913.3:244-
# 1  NC_000913.3:420+
# 2  NC_000913.3:422-
# 3  NC_000913.3:423-
# 4  NC_000913.3:475+

# %%
min_freq = 0.05
spname = "ecoli"
for spcol in filter(lambda c: c.endswith("mod_frequency"), df.columns):
    #spname = spcol.split("_")[1]
    if spname not in species2motifs: 
        print(spname, "is missing")
        continue
    _df = df[(df[spcol]>=min_freq)&(df["chr"].isin(species2refs[spname]))]
    data = []
    # depth 6mA	5mC	mean 6mA freq	mean m5C freq	positions
    data.append(2*_df[spcol.replace("mod_frequency", "depth")].mean())
    # get number of every modification
    for mod in mod2mers.keys():
        data.append((_df["mod"]==mod).sum())
    # get avg mod_freq
    for mod in mod2mers.keys():
        data.append(_df.loc[_df["mod"]==mod, spcol].mean())
    # store total number of modifications
    data.append(len(_df))    
    # get each motif penetrance
    for m, mpos in species2motifs[spname].items():
        common = mpos.intersection(_df["ref"].to_numpy())
        data.append(len(common)/len(mpos))
    print(spname, *data)
# Out:
# ecoli 904.8964473568217 38897 29165 0.6316899760907011 0.42358745071146925 68062 0.9979606776824932 0.9966672221296451 0.9978508844437097 0.0011966792870675015
# ecoli 250.80205956351296 38495 29869 0.5925278088063384 0.4410661220663565 68364 0.996705710102489 0.9988335277453758 0.9988427839312283 0.004253257707047144

# %%
# #/home/lpryszcz/cluster/dna_mods/ecoli/modPhred.2020/PRJNA477598/
fn = "/home/lpryszcz/cluster/dna_mods/ecoli/modPhred.2020/PRJNA477598/mod.gz" # PRJNA477598 PRJEB22772
df = pd.read_csv(fn, sep="\t", skiprows=16)#; df.head() 
# get ref as chr:pos + strand
df["ref"] = df['chr'].astype(str) + ":" + df['pos'].astype(str) + df['strand']; df.head()
# Out:
#            chr  pos ref_base strand  mod  \
# 0  NC_000913.3   23        C      -  5mC
# 1  NC_000913.3   24        C      -  5mC
# 2  NC_000913.3   35        A      -  5mC
# 3  NC_000913.3  123        T      -  5mC
# 4  NC_000913.3  153        C      -  5mC
#
#    modPhred/PRJNA477598/minimap2/barcode01_cneoformans_pass.bam depth  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    modPhred/PRJNA477598/minimap2/barcode01_cneoformans_pass.bam basecall_accuracy  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    modPhred/PRJNA477598/minimap2/barcode01_cneoformans_pass.bam mod_frequency  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    modPhred/PRJNA477598/minimap2/barcode01_cneoformans_pass.bam median_mod_prob  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    modPhred/PRJNA477598/minimap2/barcode01_paeruginosa_pass.bam depth  ...  \
# 0                                                  0                   ...
# 1                                                  0                   ...
# 2                                                  0                   ...
# 3                                                  0                   ...
# 4                                                  0                   ...
#
#    modPhred/PRJNA477598/minimap2/barcode08_scerevisiae_pass.bam median_mod_prob  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    modPhred/PRJNA477598/minimap2/nasa_chiu_r9.bam depth  \
# 0                                                  6
# 1                                                  7
# 2                                                  8
# 3                                                  8
# 4                                                  8
#
#    modPhred/PRJNA477598/minimap2/nasa_chiu_r9.bam basecall_accuracy  \
# 0                                              1.000
# 1                                              1.000
# 2                                              1.000
# 3                                              1.000
# 4                                              0.875
#
#    modPhred/PRJNA477598/minimap2/nasa_chiu_r9.bam mod_frequency  \
# 0                                              0.167
# 1                                              0.143
# 2                                              0.000
# 3                                              0.000
# 4                                              0.000
#
#    modPhred/PRJNA477598/minimap2/nasa_chiu_r9.bam median_mod_prob  \
# 0                                              0.516
# 1                                              0.710
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    modPhred/PRJNA477598/minimap2/nasa_mason_r9.bam depth  \
# 0                                                 13
# 1                                                 14
# 2                                                 16
# 3                                                 18
# 4                                                 19
#
#    modPhred/PRJNA477598/minimap2/nasa_mason_r9.bam basecall_accuracy  \
# 0                                              1.000
# 1                                              1.000
# 2                                              0.938
# 3                                              0.944
# 4                                              0.947
#
#    modPhred/PRJNA477598/minimap2/nasa_mason_r9.bam mod_frequency  \
# 0                                              0.000
# 1                                              0.000
# 2                                              0.062
# 3                                              0.056
# 4                                              0.105
#
#    modPhred/PRJNA477598/minimap2/nasa_mason_r9.bam median_mod_prob  \
# 0                                                NaN
# 1                                                NaN
# 2                                              0.774
# 3                                              0.806
# 4                                              0.919
#
#                 ref
# 0   NC_000913.3:23-
# 1   NC_000913.3:24-
# 2   NC_000913.3:35-
# 3  NC_000913.3:123-
# 4  NC_000913.3:153-
#
# [5 rows x 58 columns]

# %%
for spcol in filter(lambda c: c.endswith("mod_frequency"), df.columns):
    spname = spcol.split("_")[1]
    if spname not in species2motifs: 
        print(spname, "is missing")
        continue
    _df = df[(df[spcol]>=min_freq)&(df["chr"].isin(species2refs[spname]))]
    data = []
    # depth 6mA	5mC	mean 6mA freq	mean m5C freq	positions
    data.append(2*_df[spcol.replace("mod_frequency", "depth")].mean())
    # get number of every modification
    for mod in mod2mers.keys():
        data.append((_df["mod"]==mod).sum())
    # get avg mod_freq
    for mod in mod2mers.keys():
        data.append(_df.loc[_df["mod"]==mod, spcol].mean())    
    # store total number of modifications
    data.append(len(_df))
    # get each motif penetrance
    for m, mpos in species2motifs[spname].items():
        common = mpos.intersection(_df["ref"].to_numpy())
        data.append(len(common)/len(mpos))
    print(spname, *data)
# Out:
# cneoformans 65.78276113133576 17204 72071 0.13394576842594746 0.10239215495830499 89275 0.1017274472168906 0.0021475580187045374 0.001169751599807335 0.03904561765230666
# paeruginosa 147.31385435637554 65784 9990 0.26019145992946613 0.07769729729729731 75774 0.776373881015684 0.0006533812479581836 0.0007201880069744522 0.00339133192333598
# ecoli 346.96027108433736 36912 29488 0.6344618010403121 0.37014775501899083 66400 0.9391863626856306 0.9385102482919513 0.9378409654488346 0.004368600288933168
# ecoli 45.61268275073702 39511 43594 0.592452582825036 0.26199488461714915 83105 0.9376699435264589 0.928178636893851 0.9332121011737478 0.013627726049833762
# lfermentum nan 0 0 nan nan 0 0.0 0.0 0.0 0.0
# efaecalis 374.61111966733404 2052 4441 0.1252982456140351 0.08072798919162352 6493 0.13530685920577618 0.0 0.0 0.019455486773531608
# lmonocytogenes 195.55796120884077 1982 4669 0.12580575176589304 0.0788935532233883 6651 0.15637065637065636 0.0010384215991692627 0.001076426264800861 0.016851557479622553
# bsubtilis 171.59630984571336 14132 11016 0.16467258703651286 0.17000962236746547 25148 0.27367660945397987 0.48431618569636137 0.4987980769230769 0.010204378007338633
# senterica 73.40781530078154 37436 32299 0.6323762421198845 0.3194278460633456 69735 0.8810900082576383 0.8416283084004603 0.8255729090643702 0.003907230168118436
# saureus 243.84596057209123 79 10269 0.08877215189873419 0.14987213944882657 10348 0.0029222676797194622 0.0 0.0 0.04608685975015998
# scerevisiae 87.23990449496523 973 8660 0.11636176772867421 0.09157321016166282 9633 0.013924734409699298 0.0 0.00017866714311238162 0.013507732166951381
# chiu is missing
# mason is missing
